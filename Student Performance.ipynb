# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # 2. Importing Data

# %%
df_Students_perf = pd.read_csv('C:\learn python\Student.csv')

# %% [markdown]
# # 3.Reading Sample Data

# %%
df_Students_perf.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df_Students_perf.shape
# Out:
# (2392, 15)

# %%
print(df_Students_perf.columns.tolist())
# Out:
# ['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation', 'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport', 'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA', 'GradeClass']

# %%
df_Students_perf.StudentID.unique()
# Out:
# array([1001, 1002, 1003, ..., 3390, 3391, 3392], dtype=int64)

# %%
df_Students_perf.Age.value_counts()
# Out:
# 15    630
# 16    593
# 17    587
# 18    582
# Name: Age, dtype: int64

# %%
df_Students_perf.Age.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df_Students_perf.GradeClass.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_Students_perf.StudyTimeWeekly.mean()
# Out:
# 9.771991919431747

# %%
df_Students_perf.Absences.mean()
# Out:
# 14.54138795986622

# %%
df_Students_perf.describe
# Out:
# <bound method NDFrame.describe of       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %% [markdown]
# # 4. Checking Datatypes and Null Vlaues

# %%
df_Students_perf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %% [markdown]
# # 5.Creating Dimension Tables

# %%
data = {'ID':[0,1],'Male/Female':['Male','Female'],}
df_Gender =pd.DataFrame(data)
df_Gender
# Out:
#    ID Male/Female
# 0   0        Male
# 1   1      Female

# %%
df_Gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           2 non-null      int64
#  1   Male/Female  2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes

# %%
data_Ethnicity = {'ID':[0,1,2,3],'Ethnicity':['Caucasian','African American','Asian','Other']}
df_Ethnicity =pd.DataFrame(data_Ethnicity)
df_Ethnicity
# Out:
#    ID         Ethnicity
# 0   0         Caucasian
# 1   1  African American
# 2   2             Asian
# 3   3             Other

# %%
data_Parent_Edu = {'ID':[0,1,2,3,4],'Parent_Education':['None','High School','Some College','Bachelors','Higher']}
df_Parent_Edu =pd.DataFrame(data_Parent_Edu)
df_Parent_Edu
# Out:
#    ID Parent_Education
# 0   0             None
# 1   1      High School
# 2   2     Some College
# 3   3        Bachelors
# 4   4           Higher

# %%
data_Parent_Support = {'ID':[0,1,2,3,4],'Parent_Support':['None','Low','Moderate','High','Very High']}
df_Parent_Support =pd.DataFrame(data_Parent_Support)
df_Parent_Support
# Out:
#    ID Parent_Support
# 0   0           None
# 1   1            Low
# 2   2       Moderate
# 3   3           High
# 4   4      Very High

# %%
data_Activities = {'ID':[0,1],'Description':['No','Yes']}
df_Activities =pd.DataFrame(data_Activities)
df_Activities
# Out:
#    ID Description
# 0   0          No
# 1   1         Yes

# %%
data_Grade_Class = {'Grade':[0,1,2,3,4],'Class':['A','B','C','D','F'],'GPA':['GPA >= 3.5','3.0 <= GPA < 3.5','2.5 <= GPA < 3.0',
'2.0 <= GPA < 2.5','GPA < 2.0']}
df_Grade_Class =pd.DataFrame(data_Grade_Class)
df_Grade_Class
# Out:
#    Grade Class               GPA
# 0      0     A        GPA >= 3.5
# 1      1     B  3.0 <= GPA < 3.5
# 2      2     C  2.5 <= GPA < 3.0
# 3      3     D  2.0 <= GPA < 2.5
# 4      4     F         GPA < 2.0

# %% [markdown]
# # 6.Merging DataFrames

# %%
df = pd.merge(df_Students_perf,df_Gender,left_on='Gender',right_on='ID',how='inner')
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1004   17       1          0                  3        10.028829
# 2          1005   17       1          0                  2         4.672495
# 3          1008   15       1          1                  4        15.424496
# 4          1010   16       1          0                  1        18.444466
# ...         ...  ...     ...        ...                ...              ...
# 2387       3378   18       0          0                  2        12.749976
# 2388       3382   15       0          2                  0        10.095086
# 2389       3383   16       0          0                  3        13.941823
# 2390       3387   16       0          0                  2        13.814021
# 2391       3389   17       0          0                  1         7.583217
#
# ...

# %% [markdown]
# # Gender

# %%
df['Male/Female'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
count = df.groupby(['Male/Female','GradeClass']).size().to_frame('Student_count')

# %%
count
# Out:
#                         Student_count
# Male/Female GradeClass
# Female      0.0                    49
#             1.0                   137
#             2.0                   194
#             3.0                   213
#             4.0                   629
# Male        0.0                    58
#             1.0                   132
#             2.0                   197
#             3.0                   201
#             4.0                   582

# %% [markdown]
# # Ethnicity

# %%
df1 = pd.merge(df_Students_perf,df_Ethnicity,left_on='Ethnicity',right_on='ID',how='inner')
df1
# Out:
#       StudentID  Age  Gender  Ethnicity_x  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1            0                  2        19.833723
# 1          1002   18       0            0                  1        15.408756
# 2          1004   17       1            0                  3        10.028829
# 3          1005   17       1            0                  2         4.672495
# 4          1006   18       0            0                  1         8.191219
# ...         ...  ...     ...          ...                ...              ...
# 2387       3342   17       1            3                  2        14.406458
# 2388       3352   15       0            3                  2         1.889249
# 2389       3368   15       1            3                  1         9.381207
# 2390       3370   16       0            3                  3         2.147222
# 2391       3374   18       0            3                  2        19.088954
#
# ...

# %%
df['Ethnicity_y'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df1.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity_x', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass', 'ID', 'Ethnicity_y'],
#       dtype='object')

# %%
df1['GradeClass'].value_counts()
# Out:
# 4.0    1211
# 3.0     414
# 2.0     391
# 1.0     269
# 0.0     107
# Name: GradeClass, dtype: int64

# %%
count = df1.groupby(['Ethnicity_y','GradeClass']).size().to_frame('Student_count')

# %%
df = pd.DataFrame(count)

# %%
df
# Out:
#                              Student_count
# Ethnicity_y      GradeClass
# African American 0.0                    24
#                  1.0                    59
#                  2.0                    79
#                  3.0                    91
#                  4.0                   240
# Asian            0.0                    27
#                  1.0                    47
#                  2.0                    76
#                  3.0                    86
#                  4.0                   234
# Caucasian        0.0                    47
#                  1.0                   136
#                  2.0                   198
#                  3.0                   194
#                  4.0                   632
# Other            0.0                     9
#                  1.0                    27
#                  2.0                    38
#                  3.0                    43
#                  4.0                   105

# %% [markdown]
# # Parent Education

# %%
df2 = pd.merge(df_Students_perf,df_Parent_Edu,left_on='ParentalEducation',right_on='ID',how='inner')
df2
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1005   17       1          0                  2         4.672495
# 2          1014   17       0          1                  2        12.101425
# 3          1016   15       0          0                  2         9.728101
# 4          1022   15       0          0                  2        15.323142
# ...         ...  ...     ...        ...                ...              ...
# 2387       3323   16       1          1                  0        19.120394
# 2388       3334   15       0          0                  0         3.206181
# 2389       3343   15       0          0                  0        10.588715
# 2390       3382   15       0          2                  0        10.095086
# 2391       3391   16       1          1                  0        12.416653
#
# ...

# %%
df2['Parent_Education'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
count = df2.groupby(['Parent_Education','GradeClass']).size().to_frame('Student_count')

# %%
count
# Out:
#                              Student_count
# Parent_Education GradeClass
# Bachelors        0.0                    16
#                  1.0                    40
#                  2.0                    53
#                  3.0                    67
#                  4.0                   191
# High School      0.0                    30
#                  1.0                    85
#                  2.0                   127
#                  3.0                   136
#                  4.0                   350
# Higher           0.0                     2
#                  1.0                     9
#                  2.0                    13
#                  3.0                    22
#                  4.0                    74
# None             0.0                    11
#                  1.0                    27
#                  2.0                    42
#                  3.0                    39
#                  4.0                   124
# ...

# %% [markdown]
# # Absences

# %%
df2.hist(column='Absences')
# Out:
# array([[<AxesSubplot:title={'center':'Absences'}>]], dtype=object)

# %%
count = df2.groupby(['Absences','GradeClass']).size()

# %%
count
# Out:
# Absences  GradeClass
# 0         0.0           26
#           1.0           27
#           2.0           10
#           3.0            2
#           4.0            2
#                         ..
# 28        4.0           47
# 29        0.0            1
#           1.0            1
#           3.0            1
#           4.0           66
# Length: 134, dtype: int64

# %%
df2.Absences.value_counts(bins=15,ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Student Top Grades and Absences

# %%
df3 = df.loc[(df['GradeClass']==0)]
df3
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 4          1010   16       1          0                  1        18.444466
# 18         1045   18       1          0                  1        18.921512
# 39         1092   18       1          0                  2         7.724728
# 50         1112   17       1          3                  0         5.670144
# 60         1127   16       1          1                  3         5.494101
# ...         ...  ...     ...        ...                ...              ...
# 2365       3338   16       0          0                  1        13.964309
# 2369       3344   15       0          0                  1         7.909782
# 2385       3375   16       0          2                  1         2.313504
# 2386       3376   18       0          0                  2        18.925290
# 2388       3382   15       0          2                  0        10.095086
#
# ...

# %%
df3.groupby('Absences').size().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Absences'>

# %% [markdown]
# # Student Low Class and Absent Days

# %%
df_low = df.loc[(df['GradeClass']==4)]
df_low
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2          1005   17       1          0                  2         4.672495
# 3          1008   15       1          1                  4        15.424496
# 6          1018   18       1          0                  0         3.528238
# 8          1023   16       1          1                  0        18.648880
# 9          1024   18       1          3                  4        18.946138
# ...         ...  ...     ...        ...                ...              ...
# 2358       3329   17       0          0                  2         7.559367
# 2375       3354   18       0          0                  2        18.981388
# 2377       3358   17       0          2                  1        16.894183
# 2390       3387   16       0          0                  2        13.814021
# 2391       3389   17       0          0                  1         7.583217
#
# ...

# %%
df_low.groupby('Absences').size().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Absences'>

# %% [markdown]
# # Coorelation between Absences and GPA

# %%
col1,col2="Absences","GradeClass"
corr = df[col1].corr(df[col2])
corr
# Out:
# 0.7286327104548619

# %% [markdown]
# # Tutoring VS GPA

# %%
df.Tutoring.value_counts()
# Out:
# 0    1671
# 1     721
# Name: Tutoring, dtype: int64

# %%
df1 = df.loc[(df['Tutoring'] == 1)]
df1.Tutoring.value_counts()
# Out:
# 1    721
# Name: Tutoring, dtype: int64

# %%
df1.groupby(['GradeClass']).size()
# Out:
# GradeClass
# 0.0     52
# 1.0    109
# 2.0    118
# 3.0    113
# 4.0    329
# dtype: int64

# %%
### Tutoring 'Yes' and GradeClass
df1.groupby(['GradeClass']).size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GradeClass'>

# %%
df2 = df.loc[(df['Tutoring'] == 0)]
df2.Tutoring.value_counts()
# Out:
# 0    1671
# Name: Tutoring, dtype: int64

# %%
df2.groupby(['GradeClass']).size()
# Out:
# GradeClass
# 0.0     55
# 1.0    160
# 2.0    273
# 3.0    301
# 4.0    882
# dtype: int64

# %%
### Tutoring 'No' and GPA
df2.groupby(['GradeClass']).size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='GradeClass'>

# %% [markdown]
# # Study Time Weekly Vs Grades

# %%
df_Students_perf = pd.read_csv('C:\learn python\Student.csv')

# %%
df_Students_perf
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df_Students_perf.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
df2 = df.loc[(df['GradeClass'] ==0)]

# %%
df2
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 4          1010   16       1          0                  1        18.444466
# 18         1045   18       1          0                  1        18.921512
# 39         1092   18       1          0                  2         7.724728
# 50         1112   17       1          3                  0         5.670144
# 60         1127   16       1          1                  3         5.494101
# ...         ...  ...     ...        ...                ...              ...
# 2365       3338   16       0          0                  1        13.964309
# 2369       3344   15       0          0                  1         7.909782
# 2385       3375   16       0          2                  1         2.313504
# 2386       3376   18       0          0                  2        18.925290
# 2388       3382   15       0          2                  0        10.095086
#
# ...

# %%
col1,col2="StudyTimeWeekly","GPA"
corr = df[col1].corr(df[col2])
corr
# Out:
# 0.17927512685608826

# %%
df2.hist(column='StudyTimeWeekly')
# Out:
# array([[<AxesSubplot:title={'center':'StudyTimeWeekly'}>]], dtype=object)

# %% [markdown]
# # Extracurricular Activities vs Grade Class

# %%
df2 = df.loc[(df['Extracurricular']==1)]

# %%
df2.groupby('GradeClass').size().plot(kind='pie')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\ravik\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
df3 = df.loc[(df['Extracurricular']==0)]

# %%
df3.groupby('GradeClass').size().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# # Sports vs Grade Class

# %%
df2 = df.loc[(df['Sports']==1)]

# %%
df2.groupby('GradeClass').size().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='GradeClass'>

# %% [markdown]
# # Music vs Grade Class

# %%
df2 = df.loc[(df['Music']==1)]

# %%
df2.groupby('GradeClass').size().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='GradeClass'>

# %% [markdown]
# # Volunteering vs Grade Class

# %%
df2 = df.loc[(df['Volunteering']==1)]

# %%
df2.groupby('GradeClass').size().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='GradeClass'>

# %% [markdown]
# # GradeClass vs GPA

# %%
df_Students_perf = pd.read_csv('C:\learn python\Student.csv')

# %%
df2 = df_Students_perf.loc[(df_Students_perf['GradeClass']==0) & (df_Students_perf['GPA']>=3.5)]

# %%
df2
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 9          1010   16       1          0                  1        18.444466
# 44         1045   18       1          0                  1        18.921512
# 91         1092   18       1          0                  2         7.724728
# 92         1093   16       0          0                  2         9.697175
# 111        1112   17       1          3                  0         5.670144
# ...         ...  ...     ...        ...                ...              ...
# 2071       3072   17       0          0                  1         9.005304
# 2126       3127   15       1          0                  2        16.930690
# 2127       3128   17       1          0                  4        10.103314
# 2143       3144   15       0          1                  2        14.507792
# 2157       3158   17       1          2                  3        14.329525
#
# ...

# %%
df3 = df_Students_perf.loc[(df_Students_perf['GradeClass']==0) & (df_Students_perf['GPA']<3.5)]

# %%
df3
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2194       3195   15       0          0                  2        15.615710
# 2198       3199   16       1          1                  3         1.511090
# 2211       3212   17       1          0                  2         5.319481
# 2214       3215   16       0          2                  1        18.982249
# 2220       3221   18       0          0                  1         0.185050
# 2227       3228   15       0          2                  3         6.018381
# 2228       3229   15       0          2                  1         3.342686
# 2237       3238   17       0          1                  3         2.207885
# 2240       3241   15       1          2                  2        11.963649
# 2241       3242   17       0          2                  2         5.288086
# 2242       3243   15       0          0                  0        10.552489
# ...
